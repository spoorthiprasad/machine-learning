# %%
# !pip install bioinfokit  #library for visualization the thimgs related to clinical research or pathological data
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.4-py3-none-any.whl size=59220 sha256=9361bf2d29392b0ff020b030bc1fd5235ad90826f9063aae974203aa36533915
#   Stored in directory: /root/.cache/pip/wheels/45/b1/91/212510cab723ee76a25180836e8897f926820382374184b017
# Successfully built bioinfokit
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bioinfokit.visuz import cluster
from sklearn.manifold import TSNE
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("/content/TSNE_data.csv")

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#split out validation dataset
array=df.values
x=array[:,1:]
y=array[:,0]

# %%
array
# Out:
# array([['M', 17.99, 10.38, ..., 0.2654, 0.4601, 0.1189],
#        ['M', 20.57, 17.77, ..., 0.186, 0.275, 0.08902],
#        ['M', 19.69, 21.25, ..., 0.243, 0.3613, 0.08758],
#        ...,
#        ['M', 16.6, 28.08, ..., 0.1418, 0.2218, 0.0782],
#        ['M', 20.6, 29.33, ..., 0.265, 0.4087, 0.124],
#        ['B', 7.76, 24.54, ..., 0.0, 0.2871, 0.07039]], dtype=object)

# %%
df
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#TSNE visualization
data_tsne=TSNE(n_components=2).fit_transform(x)

# %%
data_tsne
# Out:
# array([[ 41.683437 , -12.677297 ],
#        [ 41.857998 ,  -9.964328 ],
#        [ 37.2788   , -10.0308485],
#        ...,
#        [ 21.891403 ,  -2.954824 ],
#        [ 39.736084 , -10.051282 ],
#        [-38.485268 , -25.483894 ]], dtype=float32)

# %%
newdf=pd.DataFrame(data_tsne).join(df['diagnosis'])

# %%
newdf
# Out:
#              0          1 diagnosis
# 0    41.683437 -12.677297         M
# 1    41.857998  -9.964328         M
# 2    37.278801 -10.030849         M
# 3   -18.052645   2.106157         M
# 4    36.115978  -7.962190         M
# ..         ...        ...       ...
# 564  43.380466  -9.347517         M
# 565  38.202274  -9.400380         M
# 566  21.891403  -2.954824         M
# 567  39.736084 -10.051282         M
# 568 -38.485268 -25.483894         B
#
# [569 rows x 3 columns]

# %%
# get a list of categories
color_class = df['diagnosis'].to_numpy()
# Convert dataframe to array. legnedpos=position on upper right corner showing color difference, colorlist-show different color for M and B in diagnosis column
cluster.tsneplot(score=data_tsne, colorlist=color_class, legendpos='upper right',legendanchor=(1.15,1)) # legendanchor - sets position of M and B color box, if not given shows by default inside big rectangle
plt.show()
#Plot will be stored in the default directory
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.

# %%
color_class
